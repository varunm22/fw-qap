# %%
#import sys
#import numpy as np
#from sfw import sfw
#import utils
#import matplotlib.pyplot as plt
from test_helpers import *

# %% [markdown]
# ### Exact LAP and exact line search for step size
#
# This first test uses an exact LAP solver and uses an exact line search to determine optimal step size. The plots show a histogram of n=50 costs where each datapoint corresponds to the minimum cost found among k=100 runs of SFW.

# %%
results = for_all_tests(partial(min_of_k_n_times, k=100, n=50))
for num in results:
    costs = [x[1] for x in results[num]]
    histogram(num, costs)

# %%
for num in results: 
    costs = [x[1] for x in results[num]]
    print(sum(costs)/50)
# Out:
# 10.0
# 395.0
# 314.0
# 313.0
# 524.86
# 1019.36
# 1410.58

# %%
results = for_all_tests(partial(min_of_k_n_times, k=100, n=50))
for num in results:
    costs = [x[1] for x in results[num]]
    histogram(num, costs)

# %%
for num in results: 
    costs = [x[1] for x in results[num]]
    print(sum(costs)/50)
# Out:
# 10.0
# 395.0
# 314.0
# 313.24
# 523.32
# 1022.92
# 1390.74

# %%
results = for_all_tests(partial(min_of_k_n_times, k=100, n=50))
for num in results:
    costs = [x[1] for x in results[num]]
    histogram(num, costs)

# %%
for num in results: 
    costs = [x[1] for x in results[num]]
    print(sum(costs)/50)
# Out:
# 10.0
# 395.0
# 314.0
# 313.42
# 521.6
# 1027.54
# 1410.38

# %%
results = for_all_tests(partial(min_of_k_n_times, k=100, n=50))
for num in results:
    costs = [x[1] for x in results[num]]
    histogram(num, costs)

# %%
for num in results: 
    costs = [x[1] for x in results[num]]
    print(sum(costs)/50)
# Out:
# 10.0
# 395.0
# 314.0
# 313.0
# 512.36
# 989.68
# 1319.36
